# %%
from IPython.display import Image
Image(filename = "2.png", width=1000, height=50)

# %%
#Data analysis library
import pandas as pd

# %% [markdown]
# - read_csv() - A function to read excel file (csv format)

# %%
#read trainset
train = pd.read_csv('sample_train.csv')

#read testset
test = pd.read_csv('sample_test.csv')

# %%
#print top 5 records
train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0       88643   2019-02-22 01:14:39   342952484382519
# 1     1238538   2020-05-31 21:28:12    30371006069917
# 2       18146   2019-01-11 22:16:14  4681601008538160
# 3       70809   2019-02-11 14:41:55     4239436242473
# 4     1272336   2020-06-12 17:58:38  4681601008538160
#
#                            merchant      category     amt   first   last  \
# 0   fraud_Heller, Gutmann and Zieme   grocery_pos   81.07   Kayla  Jones
# 1  fraud_Koss, Hansen and Lueilwitz          home   27.73  Robert  James
# 2              fraud_Cartwright PLC     kids_pets  190.34   Tammy  Davis
# 3                 fraud_Ullrich Ltd     kids_pets  134.74   James   Leon
# 4                   fraud_Price Inc  shopping_net    7.66   Tammy  Davis
#
#   gender                      street  ...      lat     long  city_pop  \
# 0      F  6033 Young Track Suite 804  ...  42.0158 -73.2913       647
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Data visualization library
import seaborn as sns

# %% [markdown]
# ### Univariate Analysis - one variable analysis

# %% [raw]
# - countplot() - a function that counts categorical variable (graphical analysis)

# %%
#frequency of gender distribution
sns.countplot(x = train["gender"]);

# %% [raw]
# value_counts() - a function that counts categorical & numeric variable (non - graphical analysis)

# %%
#frequency of gender distribution
train['gender'].value_counts()
# Out:
# F    54703
# M    45297
# Name: gender, dtype: int64

# %%
#frequency of is_fraud distribution
train['is_fraud'].value_counts()
# Out:
# 0    99440
# 1      560
# Name: is_fraud, dtype: int64

# %%
#frequency of is_fraud distribution
train['cc_num'].value_counts()
# Out:
# 6011109736646996    273
# 571365235126        269
# 6011652924285713    269
# 376445266762684     260
# 36722699017270      259
#                    ...
# 4157213332670159      1
# 3543885983111461      1
# 6577777028615915      1
# 6500249000784905      1
# 6517779374888867      1
# Name: cc_num, Length: 955, dtype: int64

# %%
#make all series visible
pd.set_option('display.max_rows', None)

# %%
#frequency of is_fraud distribution
train['cc_num'].value_counts()
# Out:
# 6011109736646996       273
# 571365235126           269
# 6011652924285713       269
# 376445266762684        260
# 36722699017270         259
# 2720433095629877       257
# 630424987505           253
# 180048185037117        252
# 4836998673805450       251
# 342952484382519        249
# 4904681492230012       248
# 4745996322265          248
# 3545109339866548       246
# 213112402583773        245
# 6011504998544485       244
# 30238755902988         243
# 372509258176510        243
# 3521417320836166       240
# 6011367958204270       240
# 630451534402           239
# 345933964507467        239
# 3566094707272327       238
# 180094419304907        238
# 4939976756738216       237
# 6534628260579800       236
# 372520049757633        236
# 3583635130604947       236
# 6011438889172900       235
# 30199621383748         234
# 3596217206093829       234
# 2712209726293386       234
# 344709867813900        234
# 4586810168620942       233
# 3576431665303017       233
# ...

# %% [markdown]
# ## Bivariate Analysis - two variable analysis

# %% [raw]
# - scatterplot() - a function that tells relationship between two variables

# %%
#location of each customers
sns.scatterplot(data = train, x="lat", y="long");

# %% [markdown]
# ## Multivariate Analysis - more than two variable analysis

# %%
#location of each customers and is_fraud activity
sns.scatterplot(data= train, x="lat", y="long", hue ='is_fraud');

# %% [markdown]
# more chart - https://seaborn.pydata.org/generated/seaborn.countplot.html

# %%
#descriptive statistics - calculating some statistical data 
train.describe()
# Out:
#          Unnamed: 0        cc_num            amt            zip  \
# count  1.000000e+05  1.000000e+05  100000.000000  100000.000000
# mean   6.502823e+05  4.177757e+17      70.386721   48752.333140
# std    3.743123e+05  1.310010e+18     152.902651   26857.017051
# min    4.000000e+00  6.041621e+10       1.000000    1257.000000
# 25%    3.268738e+05  1.800429e+14       9.720000   26237.000000
# 50%    6.510740e+05  3.521417e+15      47.605000   48174.000000
# 75%    9.745952e+05  4.642255e+15      83.610000   72011.000000
# max    1.296656e+06  4.992346e+18   14112.590000   99783.000000
#
#                  lat           long      city_pop     unix_time  \
# count  100000.000000  100000.000000  1.000000e+05  1.000000e+05
# mean       38.516398     -90.185466  8.987381e+04  1.349311e+09
# std         5.086150      13.715070  3.052955e+05  1.284343e+07
# min        20.027100    -165.672300  2.300000e+01  1.325376e+09
# 25%        34.571500     -96.790900  7.430000e+02  1.338853e+09
# ...

# %% [raw]
# count - number of rows in each column
# mean - average number in each column
# min - minimum value in each column
# max - maximum value in each column
# 50% - also known as median (the middle number)

# %% [markdown]
# # NEXT: DAY 3 - FEATURE ENGINEERING
